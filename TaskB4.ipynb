# %% [markdown]
# <a href="https://colab.research.google.com/github/TanviKhare/LGMVIP--DataScience/blob/main/TaskB4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![cropped-growmore-removebg-preview.png](data:image/png;base64,...)

# %% [markdown]
# Name : Tanvi Khare
#
# Domain: Data Science
#
# Task Level: Beginner
#
# Task Number : 4
#
#
# 4)Image to Pencil Sketch with Python:
#
# We need to read the image in RBG format and then convert it to a grayscale image. This will turn an image into a classic black and white photo. Then the next thing to do is invert the grayscale image also called negative image, this will be our inverted grayscale image.Then we can finally create the pencil sketch by mixing the grayscale image with the inverted blurry image.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('/content/drive/MyDrive/LGM-VIP/pic1.jpg')

# %%
#Original Image

# cv2.imshow("Pic", img) is disabled in colab
img= cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
#Grayscale image

imgG = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(imgG,cmap="gray")

# %%
#Negative

imgI= cv2.bitwise_not(imgG)
plt.imshow(imgI,cmap="gray")

# %%
#Smooth Negative

imgS = cv2.GaussianBlur(imgI, (21, 21),sigmaX=0, sigmaY=0)
plt.imshow(imgS,cmap="gray")

# %%
#Final Image

imgF = cv2.divide(imgG, 255 - imgS, scale=255)
plt.imshow(imgF,cmap="gray")
